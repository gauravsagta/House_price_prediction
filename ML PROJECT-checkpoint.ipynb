# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#     1. CRIM      per capita crime rate by town
#     2. ZN        proportion of residential land zoned for lots over 
#                  25,000 sq.ft.
#     3. INDUS     proportion of non-retail business acres per town
#     4. CHAS      Charles River dummy variable (= 1 if tract bounds 
#                  river; 0 otherwise)
#     5. NOX       nitric oxides concentration (parts per 10 million)
#     6. RM        average number of rooms per dwelling
#     7. AGE       proportion of owner-occupied units built prior to 1940
#     8. DIS       weighted distances to five Boston employment centres
#     9. RAD       index of accessibility to radial highways
#     10. TAX      full-value property-tax rate per $10,000
#     11. PTRATIO  pupil-teacher ratio by town
#     12. B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks 
#                  by town
#     13. LSTAT    % lower status of the population
#     14. MEDV     Median value of owner-occupied homes in $1000's

# %%
housing=pd.read_csv("data.csv")

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469    NaN  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.shape
# Out:
# (506, 14)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.CHAS.value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284972
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.704110
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# housing.hist(bins=50,figsize=(20,15))
# plt.show()

# %% [markdown]
# # Train test splitting

# %%
#for learning puropose how to split data
import numpy as np
#here we are creating the test data set
def split_train_test(data,test_ratio):
    np.random.seed(42) #this is used each time we get the same random values so our train data set is not revealed
    shuffled=np.random.permutation(len(data))
    test_set_size=int(len(data) * test_ratio)
    test_indices=shuffled[:test_set_size]
    train_indices=shuffled[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
train_set,test_set=split_train_test(housing,0.2)

# %%
print(" rows in train set:" ,len(train_set))
# Out:
#  rows in train set: 405

# %%
print(" rows in test set:" ,len(test_set))
# Out:
#  rows in test set: 101

# %%
# with the help of sklearn we can directly split the data
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)

# %%
print(" rows in train set:" ,len(train_set))
# Out:
#  rows in train set: 404

# %%
print(" rows in test set:" ,len(test_set))
# Out:
#  rows in test set: 102

# %%
# here the possibility is that may be possible that in test data all those values gone which have only value 1
# so our model will not be aware about other values also it will work according to only 0 
# so we use stratified sampling include the items in test data which use every values 0 and 1 both if others include that values to

# %%
from sklearn.model_selection import StratifiedShuffleSplit  
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in split.split(housing,housing.CHAS): #spitting on the basis that 1 and 0 are equal in no in both test and train data set
    strat_train_set=housing.loc[train_index]
    strat_test_set=housing.loc[test_index]

# %%
strat_test_set.CHAS.value_counts() #using stratified we get same ratio of 0 and 1 in test and train set thats why we use stratified
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
strat_train_set.CHAS.value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
housing=strat_train_set.copy()

# %% [markdown]
# # Looking for correlations

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(housing.corr(),annot=True)
# Out:
# <Axes: >

# %%
from pandas.plotting import scatter_matrix
attributes=['RM','ZN','MEDV','LSTAT']
scatter_matrix(housing[attributes],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind="scatter",x='RM',y='MEDV',alpha=0.8) #checking outliers  #here is some mistake in data  as the correlation between the RW and MEDV is positive but here in graph at less RM value of MEDV is same as in more RM
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
from scipy import stats

z_scores = stats.zscore(housing)
threshold = 3
outliers = housing[(z_scores > threshold).any(axis=1)]

# %%
outliers
# Out:
#          CRIM     ZN  INDUS  CHAS     NOX     RM    AGE      DIS  RAD  TAX  \
# 254   0.04819   80.0   3.64     0  0.3920  6.108   32.0   9.2203    1  315
# 348   0.01501   80.0   2.01     0  0.4350  6.635   29.7   8.3440    4  280
# 57    0.01432  100.0   1.32     0  0.4110  6.816   40.5   8.3248    5  256
# 413  28.65580    0.0  18.10     0  0.5970  5.155  100.0   1.5894   24  666
# 199   0.03150   95.0   1.47     0  0.4030  6.975   15.3   7.6534    3  402
# 142   3.32105    0.0  19.58     1  0.8710  5.403  100.0   1.3216    5  403
# 234   0.44791    0.0   6.20     1  0.5070  6.726   66.5   3.6519    8  307
# 373  11.10810    0.0  18.10     0  0.6680  4.906  100.0   1.1742   24  666
# 414  45.74610    0.0  18.10     0  0.6930  4.519  100.0   1.6582   24  666
# 200   0.01778   95.0   1.47     0  0.4030  7.135   13.9   7.6534    3  402
# 353   0.01709   90.0   2.02     0  0.4100  6.728   36.1  12.1265    5  187
# ...

# %% [markdown]
# # TRYING ATTRIBUTE COMBINATION

# %%
housing["TAXRM"]=housing.TAX/housing.RM

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# 348     17.0  390.94   5.99  24.5   42.200452
# 476     20.2  396.21  18.68  16.7  102.714374
# 321     19.6  396.90   6.87  23.1   45.012547
# 326     19.6  396.90   6.15  23.0   45.468948

# %%
corr_matrix=housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.679257
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.527526
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
housing.plot(kind="scatter",x="TAXRM",y="MEDV",alpha=0.5)
# Out:
# <Axes: xlabel='TAXRM', ylabel='MEDV'>

# %%
housing = strat_train_set.drop("MEDV",axis=1)
housing_labels=strat_train_set["MEDV"].copy()

# %% [markdown]
# # missing attributes

# %%
# to take care of missing attributes, you have three options:
#     1: remove the missing data points
#     2: remove the whole attribute
#     3: set the value to some value(mean , median or etc)

# %%
housing.dropna(subset=["RM"]) #option1 removed the rows having missing values
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %%
housing.drop("RM",axis=1) #option2 dropped the column named RM 
#original dataframe remain unchanged if we put inplace=True then only original dataframe is affected
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX   AGE     DIS  RAD  TAX  PTRATIO  \
# 254  0.04819  80.0   3.64     0  0.392  32.0  9.2203    1  315     16.4
# 348  0.01501  80.0   2.01     0  0.435  29.7  8.3440    4  280     17.0
# 476  4.87141   0.0  18.10     0  0.614  93.6  2.3053   24  666     20.2
# 321  0.18159   0.0   7.38     0  0.493  54.3  4.5404    5  287     19.6
# 326  0.30347   0.0   7.38     0  0.493  28.9  5.4159    5  287     19.6
# ..       ...   ...    ...   ...    ...   ...     ...  ...  ...      ...
# 155  3.53501   0.0  19.58     1  0.871  82.6  1.7455    5  403     14.7
# 423  7.05042   0.0  18.10     0  0.614  85.1  2.0218   24  666     20.2
# 98   0.08187   0.0   2.89     0  0.445  36.9  3.4952    2  276     18.0
# 455  4.75237   0.0  18.10     0  0.713  86.5  2.4358   24  666     20.2
# 216  0.04560   0.0  13.89     1  0.550  56.0  3.1121    5  276     16.4
#
#           B  LSTAT
# 254  392.89   6.57
# 348  390.94   5.99
# 476  396.21  18.68
# 321  396.90   6.87
# ...

# %%
median=housing.RM.median()
median
# Out:
# 6.21

# %%
housing['RM'].fillna(median) #option3
#original dataframe remain unchanged
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
housing.shape
# Out:
# (404, 13)

# %%
housing.describe() #before we started filling missing attributes
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.278577
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.714871
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.877250
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
#to fit the median where values are missing we are using sklearn class 
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_ #median for all the 15 columns
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21000e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
x=imputer.transform(housing)

# %%
housing_tr=pd.DataFrame(x,columns=housing.columns) #in this dataframe medain will be will where in any column we have missing values and median is filled according to their column median

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.277899
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.711347
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# # Scikit-learn Design

# %% [markdown]
# primarily three types of objects
# 1- estimators- it estimates some parameter based on dataset. eg-imputer
# it has a fit method and transform method.
# fit method- fits the dataset and calculates internal parameters.
# 2- transformers- tensform method takes input and returns output based on the learning from fit().it also has a convenience function called fit_transform()
# which fits and then transforms.
# 3- predictors-linearRegression model is an example of predictor.
# fit() and predict() are two common funtions.

# %% [markdown]
# # feature scaling

# %%
# primarily two types of feature scaling methods;
# 1- Min-max scaling(normalizatiion)
#  (value-min)/(max-min)
    
# 2- standardization
# (value-mean)/std

# %% [markdown]
# # creating pipline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([
    ('imputer',SimpleImputer(strategy="median")),
    ('std_scaler',StandardScaler()),
])

# %%
housing_num_tr=my_pipeline.fit_transform(housing_tr)

# %%
housing_num_tr
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# # selecting a desired model

# %%
#using decision regressior
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model=LinearRegression()
#model=DecisionTreeRegressor()
model=RandomForestRegressor()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data=housing.iloc[:5]

# %%
some_labels=housing_labels.iloc[:5]

# %%
prepared_data=my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.483, 25.598, 16.434, 23.414, 23.387])

# %%
some_labels
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: MEDV, dtype: float64

# %% [markdown]
# # EVALUATING THE MODEL

# %%
from sklearn.metrics import mean_squared_error
housing_predictions=model.predict(housing_num_tr)
mse=mean_squared_error(housing_labels,housing_predictions)
rmse=np.sqrt(mse)

# %%
rmse #over fitting on train set data
# Out:
# 1.164476386600645

# %% [markdown]
# # using better evaluation technique-Cross validation

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,housing_num_tr,housing_labels,scoring="neg_mean_squared_error",cv=10)
rmse_scores=np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([2.84612412, 2.68554798, 4.45171375, 2.5549812 , 3.2879514 ,
#        2.71446034, 4.5954014 , 3.48583952, 3.25222094, 3.22382401])

# %%
def print_scores(scores):
    print("scores",scores)
    print("mean",scores.mean())
    print("standard deviation",scores.std())

# %%
print_scores(rmse_scores)
# Out:
# scores [2.84612412 2.68554798 4.45171375 2.5549812  3.2879514  2.71446034
#  4.5954014  3.48583952 3.25222094 3.22382401]
# mean 3.3098064658667803
# standard deviation 0.6728877389566218

# %% [markdown]
# # saving the model

# %%
from joblib import dump, load
dump(model, 'ml_project.joblib')
# Out:
# ['ml_project.joblib']

# %% [markdown]
# # testing the model on test data

# %%
X_test=strat_test_set.drop("MEDV",axis=1)
Y_test=strat_test_set["MEDV"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions=model.predict(X_test_prepared)
final_mse=mean_squared_error(Y_test,final_predictions)
final_rmse=np.sqrt(final_mse)
print(final_predictions,list(Y_test))
# Out:
# [24.757 11.411 25.315 21.983 18.202 15.119 20.945 14.591 31.55  40.237
#  19.914 11.715 24.186 27.796 19.634 10.641 31.22  14.492 23.576 18.716
#  19.649 17.598 16.902 22.074 18.365 30.589 16.233 32.602  8.88  33.318
#  23.687 21.293 22.993 10.793 21.003 11.301 42.49  24.292 23.539 41.757
#  23.836 29.492 20.315 20.953 19.19  33.35  44.219 20.046 20.133 21.653
#  21.619 14.701 21.362 14.98  24.656 33.055 42.718 28.892 19.503 20.841
#  47.239 10.033 18.819 25.391 14.918 32.651 19.55  18.047 18.929 33.619
#  27.389 22.785 21.486 22.714 34.705 13.088 15.872 20.205 20.696 21.376
#  22.299 21.244 14.445 23.507 20.704 21.187 13.866 21.357 21.825 23.202
#  18.703 26.871  7.275 25.942 18.592 29.956 19.815 30.881 14.698 26.468
# ...

# %%
final_rmse
# Out:
# 2.888046383243298

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.23913666, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %% [markdown]
# # using the model

# %%
from joblib import dump, load
import numpy as np
model=load('ml_project.joblib')

# %%
input=np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.23913666, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
       -0.97491834,  0.41164221, -0.86091034]])
model.predict(input)
# Out:
# array([22.483])
